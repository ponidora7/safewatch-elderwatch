# %%
# Jalankan di Python interpreter atau Jupyter Notebook
import tensorflow as tf
import cv2
import mediapipe as mp
from ultralytics import YOLO
import pandas as pd
import numpy as np

print("✅ Semua module utama berhasil di-import!")
# Out:
# WARNING:tensorflow:From c:\Users\dell\Downloads\saftwatch-20260522T130212Z-3-001\saftwatch\SafeWatch\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\dell\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Semua module utama berhasil di-import!
